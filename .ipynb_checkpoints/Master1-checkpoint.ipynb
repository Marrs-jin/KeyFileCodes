# %%
element_list = ['BaII', 'BeII', 'CaII', 'Cs', 'Fr', 'K', 'Li', 
                'MgII', 'Na', 'RaII', 'Rb', 'SrII']
for tt in range(len(element_list)):
    element = element_list[tt]
    try:
        # %run -i TransitionManualInput.py
    except (RuntimeError, TypeError, NameError, IndexError):
        print("THERE IS SOME ERROR in TR, ME, ALL!")
        break
for tt in range(len(element_list)):
    element = element_list[tt]
    try:
        # %run -i OtherData.py
    except (RuntimeError, TypeError, NameError, IndexError):
        print("THERE IS SOME ERROR in Other!")
        break
# Out:
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mats['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['modif'] = ''
# d:\python3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial'] = inits
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay'] = decs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei'] = eis
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef'] = efs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei_unc'] = eis_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef_unc'] = efs_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values('Ei', inplace = True)
# d:\python3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# d:\python3\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['mat_werr'] = mat_werr
# d:\python3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:487: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values(by=['l', 'n', 's','nf', 'lf', 'sf'], ascending = [True, True, True, True, True, True], inplace = True)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:555: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial_form'] = ini_hold #formatted
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay_form'] = dec_hold
# d:\python3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Replaced Values, experimental index, all_state index
# 0 73
# 1 76
# 2 72
# 3 74
# 4 75
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = WavelengthsCm
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = WavelengthsUncAng
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['transition_rate s-1'] = TransitionRates
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Terr'] = TransitionRateErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['branching ratio'] = BranchingRatios
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:703: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Berr'] = BranchingRatioErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_wave'] = precise_wave
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:748: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_Eerr'] = precise_Eerr
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = new_wavelength
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = new_wave_error
# No duplicated Errors, can run error calc2
# 6.3(15)E+02
# 6.5(13)E+02
# 8.6(21)E+02
# 9.2(19)E+02
# 1.14(29)E+03
# 1.26(27)E+03
# 2 Number of different data points in all arrays
# Not all values match between Adam and Safronova error format
# 510 510
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mats['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['modif'] = ''
# d:\python3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial'] = inits
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay'] = decs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei'] = eis
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef'] = efs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei_unc'] = eis_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef_unc'] = efs_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values('Ei', inplace = True)
# d:\python3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# d:\python3\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['mat_werr'] = mat_werr
# d:\python3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:487: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values(by=['l', 'n', 's','nf', 'lf', 'sf'], ascending = [True, True, True, True, True, True], inplace = True)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:555: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial_form'] = ini_hold #formatted
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay_form'] = dec_hold
# d:\python3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = WavelengthsCm
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = WavelengthsUncAng
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['transition_rate s-1'] = TransitionRates
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Terr'] = TransitionRateErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['branching ratio'] = BranchingRatios
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:703: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Berr'] = BranchingRatioErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_wave'] = precise_wave
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:748: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_Eerr'] = precise_Eerr
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = new_wavelength
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = new_wave_error
# No duplicated Errors, can run error calc2
# 3 Number of different data points in all arrays
# Not all values match between Adam and Safronova error format
# 441 441
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mats['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['modif'] = ''
# d:\python3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial'] = inits
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay'] = decs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei'] = eis
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef'] = efs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei_unc'] = eis_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef_unc'] = efs_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values('Ei', inplace = True)
# d:\python3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# d:\python3\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['mat_werr'] = mat_werr
# d:\python3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:487: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values(by=['l', 'n', 's','nf', 'lf', 'sf'], ascending = [True, True, True, True, True, True], inplace = True)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:555: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial_form'] = ini_hold #formatted
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay_form'] = dec_hold
# d:\python3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Replaced Values, experimental index, all_state index
# 0 73
# 1 76
# 2 74
# 3 75
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = WavelengthsCm
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = WavelengthsUncAng
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['transition_rate s-1'] = TransitionRates
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Terr'] = TransitionRateErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['branching ratio'] = BranchingRatios
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:703: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Berr'] = BranchingRatioErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_wave'] = precise_wave
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:748: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_Eerr'] = precise_Eerr
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = new_wavelength
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = new_wave_error
# No duplicated Errors, can run error calc2
# 6.5(10)E+02
# 8.5(14)E+02
# 9.0(15)E+02
# 1.14(19)E+03
# 1.21(20)E+03
# 3 Number of different data points in all arrays
# Not all values match between Adam and Safronova error format
# 489 489
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mats['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['modif'] = ''
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial'] = inits
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay'] = decs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei'] = eis
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef'] = efs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei_unc'] = eis_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef_unc'] = efs_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values('Ei', inplace = True)
# d:\python3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# d:\python3\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['mat_werr'] = mat_werr
# d:\python3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:487: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values(by=['l', 'n', 's','nf', 'lf', 'sf'], ascending = [True, True, True, True, True, True], inplace = True)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:555: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial_form'] = ini_hold #formatted
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay_form'] = dec_hold
# d:\python3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# d:\python3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Replaced Values, experimental index, all_state index
# 0 72
# 1 73
# 2 0
# 3 1
# 4 75
# 5 79
# 6 76
# 7 80
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = WavelengthsCm
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = WavelengthsUncAng
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['transition_rate s-1'] = TransitionRates
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Terr'] = TransitionRateErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['branching ratio'] = BranchingRatios
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:703: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Berr'] = BranchingRatioErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_wave'] = precise_wave
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:748: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_Eerr'] = precise_Eerr
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = new_wavelength
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = new_wave_error
# No duplicated Errors, can run error calc2
# 4.12(10)E+03
# 6 Number of different data points in all arrays
# Not all values match between Adam and Safronova error format
# 489 489
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:79: SettingWithCopyWarning:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = WavelengthsCm
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = WavelengthsUncAng
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['transition_rate s-1'] = TransitionRates
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Terr'] = TransitionRateErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['branching ratio'] = BranchingRatios
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:703: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Berr'] = BranchingRatioErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_wave'] = precise_wave
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:748: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_Eerr'] = precise_Eerr
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = new_wavelength
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = new_wave_error
# No duplicated Errors, can run error calc2
# 2 Number of different data points in all arrays
# Not all values match between Adam and Safronova error format
# 489 489
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mats['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['old_unc'] = database['unc']
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['modif'] = ''
# d:\python3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial'] = inits
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay'] = decs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei'] = eis
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef'] = efs
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ei_unc'] = eis_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Ef_unc'] = efs_unc
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values('Ei', inplace = True)
# d:\python3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# d:\python3\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['mat_werr'] = mat_werr
# d:\python3\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:487: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state.sort_values(by=['l', 'n', 's','nf', 'lf', 'sf'], ascending = [True, True, True, True, True, True], inplace = True)
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:555: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Initial_form'] = ini_hold #formatted
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Decay_form'] = dec_hold
# d:\python3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Replaced Values, experimental index, all_state index
# 0 60
# 1 59
# 2 58
# 3 57
# 4 56
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = WavelengthsCm
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = WavelengthsUncAng
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['transition_rate s-1'] = TransitionRates
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Terr'] = TransitionRateErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['branching ratio'] = BranchingRatios
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:703: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Berr'] = BranchingRatioErrors
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_wave'] = precise_wave
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:748: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['precise_Eerr'] = precise_Eerr
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['wavelength'] = new_wavelength
# C:\Users\dmgame\Documents\SafronovaResearch\LifetimesWebsite - Copy\LoadInElement.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_state['Eerr'] = new_wave_error
# No duplicated Errors, can run error calc2
